# %%
import pandas as pd

# %%
pd.options.display.max_columns = 88

# %%
# Cambiar ruta a la oficial Google Cloud para no depender del local

df = pd.read_csv("https://storage.googleapis.com/datamexico-data/inegi_intercensal_census/TR_PERSONA01.CSV", 
                 encoding="latin-1",
                 dtype=str,
                 low_memory=False)

# %%
# Coordinar columnas con sheets
df.columns = map(str.lower, df.columns)

# %%
df.head()
# Out:
#         id_viv     id_persona ent         nom_ent  mun         nom_mun loc50k  \
# 0  10010000001  1001000000102  01  Aguascalientes  001  Aguascalientes   0001
# 1  10010000001  1001000000103  01  Aguascalientes  001  Aguascalientes   0001
# 2  10010000001  1001000000104  01  Aguascalientes  001  Aguascalientes   0001
# 3  10010000001  1001000000101  01  Aguascalientes  001  Aguascalientes   0001
# 4  10010000002  1001000000206  01  Aguascalientes  001  Aguascalientes   0001
#
#           nom_loc cobertura    estrato     upm factor numper sexo edad parent  \
# 0  Aguascalientes         2  01-001-05  000041     15      2    3   35      2
# 1  Aguascalientes         2  01-001-05  000041     15      3    3   12      3
# 2  Aguascalientes         2  01-001-05  000041     15      4    1    5      3
# 3  Aguascalientes         2  01-001-05  000041     15      1    1   37      1
# 4  Aguascalientes         2  01-001-06  000136     35      6    1    5      3
#
#   parent_otro_c ident_madre ident_padre sersalud afrodes acta_nac dhsersal1  \
# 0           201          96          97        5       3        1         1
# 1           301           2           1        5       3        1         1
# 2           301           2           1        5       3        1         1
# 3           101          96          96        5       3        1         1
# 4           301           2           1        1       3        1         2
#
#   dhsersal2 perte_indigena ent_pais_nac nacionalidad hlengua qdialect_c  \
# 0       NaN              1          001            5       3        NaN
# 1       NaN              1          001            5       3        NaN
# 2       NaN              1          001            5       3        NaN
# 3       NaN              1          032            5       3        NaN
# 4       NaN              3          001            5       3        NaN
#
#   qdialect_inali hespanol elengua asisten mun_asi     nom_mun_asi  \
# 0            NaN      NaN       3       7     NaN             NaN
# 1            NaN      NaN       3       5     001  Aguascalientes
# 2            NaN      NaN       3       5     001  Aguascalientes
# 3            NaN      NaN       3       7     NaN             NaN
# 4            NaN      NaN       3       5     001  Aguascalientes
#
#   ent_pais_asi tie_traslado_escu med_traslado_esc1 med_traslado_esc2  \
# 0          NaN               NaN               NaN               NaN
# 1          001                 1                 6               NaN
# 2          001                 2                 6               NaN
# 3          NaN               NaN               NaN               NaN
# 4          001                 1                 6               NaN
#
#   med_traslado_esc3 escolari nivacad alfabet escoacum mun_res10  \
# 0               NaN        6       2       5        6       001
# 1               NaN        4       2       5        4       001
# 2               NaN        2       1       7        0       001
# 3               NaN        6       2       5        6       001
# 4               NaN        0       0       9        0       001
#
#     nom_mun_res10 ent_pais_res10 situa_conyugal ident_pareja conact  \
# 0  Aguascalientes            001              1            1     33
# 1  Aguascalientes            001              6          NaN     31
# 2  Aguascalientes            001            NaN          NaN    NaN
# 3  Aguascalientes            001              1            2     10
# 4  Aguascalientes            001            NaN          NaN    NaN
#
#   ocupacion_c situacion_trab aguinaldo vacaciones servicio_medico utilidades  \
# 0         NaN            NaN       NaN        NaN             NaN        NaN
# 1         NaN            NaN       NaN        NaN             NaN        NaN
# 2         NaN            NaN       NaN        NaN             NaN        NaN
# 3         834              1         1          3               5          7
# 4         NaN            NaN       NaN        NaN             NaN        NaN
#
#   incap_sueldo sar_afore credito_vivienda ingtrmen actividades_c mun_trab  \
# 0          NaN       NaN              NaN      NaN           NaN      NaN
# 1          NaN       NaN              NaN      NaN           NaN      NaN
# 2          NaN       NaN              NaN      NaN           NaN      NaN
# 3            1         3                5     3857          4611      001
# 4          NaN       NaN              NaN      NaN           NaN      NaN
#
#      nom_mun_trab ent_pais_trab tie_traslado_trab med_traslado_trab1  \
# 0             NaN           NaN               NaN                NaN
# 1             NaN           NaN               NaN                NaN
# 2             NaN           NaN               NaN                NaN
# 3  Aguascalientes           001                 1                  6
# 4             NaN           NaN               NaN                NaN
#
#   med_traslado_trab2 med_traslado_trab3 acti_sin_pago1 acti_sin_pago2  \
# 0                NaN                NaN              0              0
# 1                NaN                NaN              0              0
# 2                NaN                NaN            NaN            NaN
# 3                NaN                NaN              0              0
# 4                NaN                NaN            NaN            NaN
#
#   acti_sin_pago3 acti_sin_pago4 acti_sin_pago5 acti_sin_pago6 acti_sin_pago7  \
# 0             40             40              0             12             15
# 1              0              0              0              0              5
# 2            NaN            NaN            NaN            NaN            NaN
# 3             15             20              0              0              7
# 4            NaN            NaN            NaN            NaN            NaN
#
#   acti_sin_pago8 hijos_nac_vivos hijos_fallecidos hijos_sobreviv fecha_nac_m  \
# 0              1               4                0              4           4
# 1              1               0              NaN            NaN         NaN
# 2            NaN             NaN              NaN            NaN         NaN
# 3              1             NaN              NaN            NaN         NaN
# 4            NaN             NaN              NaN            NaN         NaN
#
#   fecha_nac_a sobrevivencia edad_morir_d edad_morir_m edad_morir_a tamloc
# 0        2009             1          NaN          NaN          NaN      5
# 1         NaN           NaN          NaN          NaN          NaN      5
# 2         NaN           NaN          NaN          NaN          NaN      5
# 3         NaN           NaN          NaN          NaN          NaN      5
# 4         NaN           NaN          NaN          NaN          NaN      5

# %%
# Agregar columnas de ids y rename de factor a population
df["mun_id"] = df["ent"] + df["mun"]
df["loc_id"] = df["mun_id"] + df["loc50k"]
df.rename(index=str, columns={"factor":"population"}, inplace=True)

# %%
# Convertir elementos necesarios a int
df["mun_id"] = df["mun_id"].astype(int)
df["loc_id"] = df["loc_id"].astype(int)
df["population"] = df["population"].astype(int)

# %%
# Separar columnas en 3 listas: 
                                # values, columnas de enteros
                                # params, parametros a trabajar
                                # sides, columnas en el spreedsheet no agregadas todavia

values = [
    "mun_id",
    "loc_id",
    "population"
]

params = [
    "sexo",
    "parent",
    "sersalud",
    "dhsersal1",
    "nacionalidad"
]

sides = [
    "ident_madre",
    "ident_padre",
    "tamloc",
    "conact"
]

# %%
# Cargar spreedsheet para realizar los cambios a la tabla de Personas
df_labels = pd.ExcelFile("https://docs.google.com/spreadsheets/d/e/2PACX-1vR08Js9Sh4nNTMe5uBcsDUFedG5MOjIf90p6EHAr1_sWY5kpnI3xUvyPHzQpTEUrXz1pskaoc0uyea6/pub?output=xlsx")

for sheet in params:
    df_l = pd.read_excel(df_labels, sheet)
    print(sheet)
    df[sheet] = df[sheet].astype(int)
    df[sheet] = df[sheet].replace(dict(zip(df_l.prev_id, df_l.id)))
# Out:
# sexo
# parent
# sersalud
# dhsersal1
# nacionalidad

# %%
df[params].head()
# Out:
#    sexo  parent  sersalud  dhsersal1  nacionalidad
# 0     2       2         5          1             1
# 1     2       3         5          1             1
# 2     1       3         5          1             1
# 3     1       1         5          1             1
# 4     1       3         1          2             1

# %%
df = df.groupby(params + ["mun_id", "loc_id"]).sum().reset_index()

# %%
df
# Out:
#       sexo  parent  sersalud  dhsersal1  nacionalidad  mun_id    loc_id  \
# 0        1       1         0          0             0    1001  10010001
# 1        1       1         0          0             0    1007  10070000
# 2        1       1         0          0             1    1009  10090000
# 3        1       1         0          1             1    1002  10020000
# 4        1       1         0          1             1    1003  10030000
# 5        1       1         0          1             1    1007  10070000
# 6        1       1         0          1             1    1008  10080000
# 7        1       1         0          1             1    1010  10100000
# 8        1       1         0          2             1    1001  10010000
# 9        1       1         0          2             1    1005  10050000
# 10       1       1         0          3             1    1005  10050000
# 11       1       1         0          8             1    1001  10010001
# 12       1       1         1          0             1    1001  10010001
# 13       1       1         1          0             1    1003  10030000
# 14       1       1         1          0             1    1004  10040000
# 15       1       1         1          0             1    1005  10050000
# 16       1       1         1          1             1    1001  10010000
# 17       1       1         1          1             1    1001  10010001
# 18       1       1         1          1             1    1002  10020000
# 19       1       1         1          1             1    1003  10030000
# 20       1       1         1          1             1    1004  10040000
# 21       1       1         1          1             1    1005  10050000
# 22       1       1         1          1             1    1006  10060000
# 23       1       1         1          1             1    1007  10070000
# 24       1       1         1          1             1    1008  10080000
# 25       1       1         1          1             1    1009  10090000
# 26       1       1         1          1             1    1010  10100000
# 27       1       1         1          1             1    1011  10110000
# 28       1       1         1          2             0    1001  10010001
# 29       1       1         1          2             0    1004  10040000
# ...    ...     ...       ...        ...           ...     ...       ...
# 4423     2      99         5          1             1    1009  10090000
# 4424     2      99         5          1             1    1010  10100000
# 4425     2      99         5          1             1    1011  10110000
# 4426     2      99         5          2             1    1002  10020000
# 4427     2      99         5          5             1    1009  10090000
# 4428     2      99         5          8             1    1005  10050000
# 4429     2      99         5          8             1    1006  10060000
# 4430     2      99         5          8             1    1010  10100000
# 4431     2      99         5          8             1    1011  10110000
# 4432     2      99         6          2             1    1001  10010001
# 4433     2      99         6          2             1    1007  10070000
# 4434     2      99         6          3             1    1007  10070000
# 4435     2      99         6          6             1    1010  10100000
# 4436     2      99         6          8             0    1001  10010001
# 4437     2      99         6          8             1    1001  10010001
# 4438     2      99         6          8             1    1002  10020000
# 4439     2      99         6          8             1    1005  10050000
# 4440     2      99         6          8             1    1006  10060000
# 4441     2      99         6          8             1    1007  10070000
# 4442     2      99         6          8             1    1008  10080000
# 4443     2      99         6          8             1    1009  10090000
# 4444     2      99         6          8             1    1011  10110000
# 4445     2      99         7          1             1    1003  10030000
# 4446     2      99         7          1             1    1004  10040000
# 4447     2      99         7          1             1    1007  10070000
# 4448     2      99         7          2             1    1007  10070000
# 4449     2      99         7          2             1    1011  10110000
# 4450     2      99         7          8             1    1001  10010000
# 4451     2      99         7          8             1    1001  10010001
# 4452     2      99         7          8             1    1007  10070000
#
#       population
# 0             24
# 1              4
# 2              2
# 3              7
# 4              4
# 5              4
# 6              4
# 7              2
# 8              9
# 9             16
# 10             7
# 11            48
# 12             4
# 13            10
# 14             2
# 15             6
# 16           189
# 17          1177
# 18           186
# 19           233
# 20            53
# 21           279
# 22            98
# 23           104
# 24            14
# 25            39
# 26            44
# 27           151
# 28           231
# 29             2
# ...          ...
# 4423          13
# 4424          18
# 4425          11
# 4426           8
# 4427           2
# 4428           6
# 4429           6
# 4430           2
# 4431           4
# 4432          75
# 4433           4
# 4434           4
# 4435           2
# 4436           1
# 4437          46
# 4438           4
# 4439           7
# 4440           8
# 4441           4
# 4442           1
# 4443           4
# 4444           4
# 4445           8
# 4446           1
# 4447           4
# 4448           4
# 4449           3
# 4450          10
# 4451          43
# 4452           4
#
# [4453 rows x 8 columns]
